# %%
import pandas as pd
df = pd.read_csv('../model_logs.csv')

# %%
df.head()
# Out:
#          Date                                        Prompt  \
# 0  2023-01-01        Write a sci-fi short story set in 2050
# 1  2023-01-02  Generate a creative story about space travel
# 2  2023-01-03   Write a poem about the future of technology
# 3  2023-01-04      Draft a speech for a graduation ceremony
# 4  2023-01-05        Write a sci-fi short story set in 2050
#
#    Response Time (ms)  Tokens Generated
# 0                  56               464
# 1                  48               351
# 2                  69               276
# 3                  78               381
# 4                  63               487

# %%
df.head(3)
# Out:
#          Date                                        Prompt  \
# 0  2023-01-01        Write a sci-fi short story set in 2050
# 1  2023-01-02  Generate a creative story about space travel
# 2  2023-01-03   Write a poem about the future of technology
#
#    Response Time (ms)  Tokens Generated
# 0                  56               464
# 1                  48               351
# 2                  69               276

# %%
df.sample(3)
# Out:
#           Date                                          Prompt  \
# 10  2023-01-11  Generate marketing copy for a new tech product
# 37  2023-02-07    Generate a creative story about space travel
# 12  2023-01-13        Draft a speech for a graduation ceremony
#
#     Response Time (ms)  Tokens Generated
# 10                  70               363
# 37                  47               258
# 12                  93               292

# %%
random_row = df.sample()
random_row
# Out:
#           Date                                     Prompt  Response Time (ms)  \
# 68  2023-03-10  Explain quantum computing in simple terms                  72
#
#     Tokens Generated
# 68               206

# %%
random_sample = df.sample(n=5, random_state=42)
random_sample
# Out:
#           Date                                          Prompt  \
# 83  2023-03-25   Create a recipe using plant-based ingredients
# 53  2023-02-23          Write a sci-fi short story set in 2050
# 70  2023-03-12     Write a historical fiction piece about WWII
# 45  2023-02-15  Generate marketing copy for a new tech product
# 44  2023-02-14  Generate marketing copy for a new tech product
#
#     Response Time (ms)  Tokens Generated
# 83                  69               374
# 53                  83               495
# 70                  89               221
# 45                  73               232
# 44                  43               254

# %%
fraction_sample = df.sample(frac=0.3)
fraction_sample
# Out:
#           Date                                          Prompt  \
# 31  2023-02-01       Explain quantum computing in simple terms
# 25  2023-01-26         Describe the impact of AI on healthcare
# 18  2023-01-19  Generate marketing copy for a new tech product
# 80  2023-03-22   Create a recipe using plant-based ingredients
# 57  2023-02-27    Generate a creative story about space travel
# 15  2023-01-16          Write a sci-fi short story set in 2050
# 7   2023-01-08    Generate a creative story about space travel
# 46  2023-02-16    Generate a creative story about space travel
# 51  2023-02-21     Write a poem about the future of technology
# 64  2023-03-06    Generate a creative story about space travel
# 84  2023-03-26    Generate a creative story about space travel
# 49  2023-02-19        Draft a speech for a graduation ceremony
# 9   2023-01-10   Create a recipe using plant-based ingredients
# 45  2023-02-15  Generate marketing copy for a new tech product
# 11  2023-01-12          Write a sci-fi short story set in 2050
# 66  2023-03-08        Draft a speech for a graduation ceremony
# 62  2023-03-04   Create a recipe using plant-based ingredients
# 98  2023-04-09        Draft a speech for a graduation ceremony
# 97  2023-04-08    Generate a creative story about space travel
# 14  2023-01-15         Describe the impact of AI on healthcare
# 61  2023-03-03     Write a poem about the future of technology
# 76  2023-03-18          Write a sci-fi short story set in 2050
# 28  2023-01-29        Draft a speech for a graduation ceremony
# 35  2023-02-05       Explain quantum computing in simple terms
# 22  2023-01-23          Write a sci-fi short story set in 2050
# 65  2023-03-07     Write a poem about the future of technology
# 74  2023-03-16  Generate marketing copy for a new tech product
# 2   2023-01-03     Write a poem about the future of technology
# 48  2023-02-18   Create a recipe using plant-based ingredients
# 99  2023-04-10     Write a poem about the future of technology
#
#     Response Time (ms)  Tokens Generated
# 31                  52               369
# 25                  45               362
# 18                  46               492
# 80                  73               242
# 57                  82               298
# 15                  85               359
# 7                   72               419
# 46                  61               470
# 51                  38               239
# 64                  59               292
# 84                  51               410
# 49                  46               238
# 9                   35               333
# 45                  73               232
# 11                  52               300
# 66                  36               307
# 62                  80               244
# 98                  56               500
# 97                  45               309
# 14                  89               481
# 61                  87               330
# 76                  36               354
# 28                  81               395
# 35                 100               203
# 22                  84               404
# 65                  57               399
# 74                  30               236
# 2                   69               276
# 48                  88               247
# 99                  76               302
